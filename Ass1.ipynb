# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishan0704/DSBDA-Practicals/blob/main/Ass1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('/content/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Missing values check
print(df.isnull().sum(),"\n")
print(df.isnull().sum().sum(),"\n")
print(df.isnull().any(),"\n")
print(pd.isnull(df['Species']),"\n")
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#
# 0
#
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool
#
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Species, Length: 150, dtype: bool

# %%
# descriptive statistics of dataset
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# dimension of dataset
print(df.shape,"\n") # rowws and columns
print(df.ndim,"\n") # dimension of row
print(df.size,"\n")# product of rows and columns
print("No of rows :",df.shape[0],"\n")
print("No of rows :",df.shape[1],"\n")
print(df.count(axis=0),"\n")# no of rows
print(df.count(axis=1),"\n")# no of col
print(len(df.count(axis=0)),"\n")
print(len(df.count(axis=1)))
# Out:
# (150, 6)
#
# 2
#
# 900
#
# No of rows : 150
#
# No of rows : 6
#
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64
#
# 0      6
# 1      6
# 2      6
# 3      6
# 4      6
#       ..
# 145    6
# 146    6
# 147    6
# 148    6
# 149    6
# Length: 150, dtype: int64
#
# 6
#
# 150

# %%
# occurance of single instance
print(df.value_counts(df['Species']),"\n")
print(df['Species'].value_counts()['Iris-setosa'])
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
#
# 50

# %%
#diskay datatype
print(df.dtypes,"\n")
print(df.info())
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
# change datatype of variables
df['PetalLengthCm'].astype(int) # temporary
#     df['PetalLengthCm'] = df['PetalLengthCm'].astype(int)  -> permanent
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    5
# 146    5
# 147    5
# 148    5
# 149    5
# Name: PetalLengthCm, Length: 150, dtype: int64

# %%
# separate categorical and numercal attribute

#numerical=df.select_dtypes(include=['int64','float64'])
numerical=df.select_dtypes(exclude='object')
categorical=df.select_dtypes(include=['object'])
print(numerical,"\n")
print(categorical,"\n")
# print datatype of numerical and categotical variables
print(type(numerical),"\n")
print(type(categorical),"\n")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
# convert categorical data -> numerical

# 1. Using replace method

df1=df
df1['Species'].unique() # returns an array with onlu unique values
df1.replace(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],[0,1,2],inplace=True)
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
# convert categorical data -> numerical

# 2. Using label encoding method

from sklearn import preprocessing
df2=df
label_encoder=preprocessing.LabelEncoder()
df1['Species']=label_encoder.fit_transform(df1['Species'])
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
# 3 one-hot-encoder
one_hot_encoder=pd.get_dummies(df,columns=['Species'])
one_hot_encoder
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species_0  \
# 0      1            5.1           3.5            1.4           0.2       True
# 1      2            4.9           3.0            1.4           0.2       True
# 2      3            4.7           3.2            1.3           0.2       True
# 3      4            4.6           3.1            1.5           0.2       True
# 4      5            5.0           3.6            1.4           0.2       True
# ..   ...            ...           ...            ...           ...        ...
# 145  146            6.7           3.0            5.2           2.3      False
# 146  147            6.3           2.5            5.0           1.9      False
# 147  148            6.5           3.0            5.2           2.0      False
# 148  149            6.2           3.4            5.4           2.3      False
# 149  150            5.9           3.0            5.1           1.8      False
#
#      Species_1  Species_2
# ...
