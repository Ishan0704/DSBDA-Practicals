# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishan0704/DSBDA-Practicals/blob/main/Ass6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['SepalLengthCm'].plot(kind='box')
# Out:
# <Axes: >

# %%
Q1=df['SepalLengthCm'].quantile(0.25)
Q3=df['SepalLengthCm'].quantile(0.75)
IQR=Q3-Q1
lower= Q1-1.5*IQR
upper= Q3+1.5*IQR

outliers=df.query('SepalLengthCm<@lower or SepalLengthCm>@upper')
outliers
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
df['PetalLengthCm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['PetalLengthCm'].plot(kind='box')
# Out:
# <Axes: >

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['SepalWidthCm'].plot(kind='box')
# Out:
# <Axes: >

# %%
Q1=df['SepalWidthCm'].quantile(0.25)
Q3=df['SepalWidthCm'].quantile(0.75)
IQR=Q3-Q1
lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
print(df)
outliers=df.query('SepalWidthCm<@lower or SepalWidthCm>@upper')
print(outliers)

print(len(df))
df1=df.drop(outliers.index,inplace=False)

print(len(df1))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df['SepalLengthCm'],df['SepalWidthCm'])

# %%
zscore= df['PetalWidthCm']-df['PetalWidthCm'].mean()/df['PetalWidthCm'].std()
print(zscore)

outlier=df[abs(zscore)>3]
print(outliers)
# Out:
# 0     -1.370661
# 1     -1.370661
# 2     -1.370661
# 3     -1.370661
# 4     -1.370661
#          ...
# 145    0.729339
# 146    0.329339
# 147    0.429339
# 148    0.729339
# 149    0.229339
# Name: PetalWidthCm, Length: 150, dtype: float64
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 15  16            5.7           4.4            1.5           0.4
# 32  33            5.2           4.1            1.5           0.1
# 33  34            5.5           4.2            1.4           0.2
# 60  61            5.0           2.0            3.5           1.0
#
#             Species
# 15      Iris-setosa
# 32      Iris-setosa
# 33      Iris-setosa
# 60  Iris-versicolor
