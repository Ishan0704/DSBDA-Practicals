# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishan0704/DSBDA-Practicals/blob/main/Pre_requisite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df['Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
df.iloc[1:6]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df.loc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
df.iloc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
df.loc[1:5]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %% [markdown]
# Actual Prequisite Begins
# # New Section
# PreRequisite of Assignment 1
#
# 1.Load hard coded data as a data frame.
# 2. Read a text file into a data frame.
# 3.Print first 5 lines and last 3 lines of a data frame
# 4. Get data types,index,columns and values
# 5.Statistical summary of each column
# 6. Sort records by any column
# 7. Slicing Records:
#   a.Single Column
#   b. Rows 2 to 3
#   c. Multiple Columns
#   d. index location
# 8. Filtering
# a. greater than
# b.is in
# 9.creating a new column
# 10. Renaming Columns.

# %%
# 3rd...
print(df.head())
print(df.tail(3))
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# Id
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# Id
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#4th
print(df.dtypes,"\n")
print(df.index,"\n")
print(df.columns,"\n")
#print(df.values,"\n")
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
#
# RangeIndex(start=0, stop=150, step=1, name='Id')
#
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#5th
print(df.describe())
print("\n")
print(df.info())
print("\n")
summary = df.agg(['mean', 'median', 'std', 'min', 'max'])
print(summary)
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
# ...

# %%
#6th
print(df.sort_values(by='PetalWidthCm', ascending=True))
print(df.sort_values(by='PetalWidthCm', ascending=False))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# Id
# 32    33            5.2           4.1            1.5           0.1
# 13    14            4.3           3.0            1.1           0.1
# 37    38            4.9           3.1            1.5           0.1
# 9     10            4.9           3.1            1.5           0.1
# 12    13            4.8           3.0            1.4           0.1
# ..   ...            ...           ...            ...           ...
# 140  141            6.7           3.1            5.6           2.4
# 114  115            5.8           2.8            5.1           2.4
# 100  101            6.3           3.3            6.0           2.5
# 144  145            6.7           3.3            5.7           2.5
# 109  110            7.2           3.6            6.1           2.5
#
#             Species
# Id
# 32      Iris-setosa
# 13      Iris-setosa
# 37      Iris-setosa
# 9       Iris-setosa
# 12      Iris-setosa
# ..              ...
# ...

# %%
#7th

print(df.Id,"\n")
print(df.iloc[2:4],"\n")
print(df.columns,"\n")
n=int(input("Enter location :"))
print(df.iloc[n])
# Out:
# Id
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64
#
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
#
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
#
# Enter location :10
# Id                        11
# SepalLengthCm            5.4
# SepalWidthCm             3.7
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 10, dtype: object

# %%
#8
n=int(input("Enter a location and I will provide all greater than and less than ID's :"))
print(df.query('Id> @n'),"\n")
print(df.query('Id<@n'))
# Out:
# Enter a location and I will provide all greater than and less than ID's :15
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# Id
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# Id
# 15      Iris-setosa
# 16      Iris-setosa
# ...

# %%
#9
# we can directly use df['new_col']=[1,2,3,5......]
#but to fill new entries will null values we will use nan function from numpy

import numpy as np
df_new_dataset=df.assign(new_col=np.nan)
print(df_new_dataset)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# Id
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  new_col
# Id
# 0       Iris-setosa      NaN
# 1       Iris-setosa      NaN
# 2       Iris-setosa      NaN
# 3       Iris-setosa      NaN
# ...

# %%
#10
df_new_dataset.rename(columns={'new_col':'renamed_col'},inplace=False)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# Id
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  renamed_col
# Id
# 0       Iris-setosa          NaN
# 1       Iris-setosa          NaN
# 2       Iris-setosa          NaN
# ...

# %%
#trial of re-naming multiple columns
df_new_dataset.rename(columns={'Id':'ID','SepalLengthCm':'SP'},inplace=False)
# Out:
#       ID   SP  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# Id
# 0      1  5.1           3.5            1.4           0.2     Iris-setosa
# 1      2  4.9           3.0            1.4           0.2     Iris-setosa
# 2      3  4.7           3.2            1.3           0.2     Iris-setosa
# 3      4  4.6           3.1            1.5           0.2     Iris-setosa
# 4      5  5.0           3.6            1.4           0.2     Iris-setosa
# ..   ...  ...           ...            ...           ...             ...
# 145  146  6.7           3.0            5.2           2.3  Iris-virginica
# 146  147  6.3           2.5            5.0           1.9  Iris-virginica
# 147  148  6.5           3.0            5.2           2.0  Iris-virginica
# 148  149  6.2           3.4            5.4           2.3  Iris-virginica
# 149  150  5.9           3.0            5.1           1.8  Iris-virginica
#
#      new_col
# Id
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# ...
